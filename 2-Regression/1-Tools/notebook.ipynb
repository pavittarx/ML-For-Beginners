# %% [markdown]
# ### Lesson 1 / Regression
#
# (https://microsoft.github.io/ML-For-Beginners/#/2-Regression/1-Tools/README)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model, model_selection

# %% [markdown]
# - `datasets.load_diabetes()` loads the diabetes dataset, which is a built-in dataset in scikit-learn commonly used for regression tasks.
# - The parameter `return_X_y=True` tells the function to return the data as separate feature matrix and target vector instead of returning a Bunch object with additional metadata.

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape, y.shape)
# Out:
# (442, 10) (442,)

# %%
X = X[:, 2]
# reshape the data to be a 2D array - as required for plotting - by using reshape(n_rows, n_columns)
X = X.reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, y, test_size=0.33
)

model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test, color="red")
plt.plot(X_test, y_pred, color="blue", linewidth=3)
plt.xlabel("Scaled BMIs")
plt.ylabel("Disease Progression")
plt.title("A Graph Plot Showing Diabetes Progression Against BMI")
plt.show()
